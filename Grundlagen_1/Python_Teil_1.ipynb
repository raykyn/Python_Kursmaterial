# %% [markdown]
# # Block 1: Python-Grundlagen
#
# In diesem ersten Dossier wirst Du lernen, erste kurze Skripte in der Python-Programmiersprache zu schreiben. Dazu werden die grundlegenden Konzepte der Programmiersprache vermittelt.
# Folgende Lernziele sind zu erreichen:
# - Du bist mit dem Nutzen von Python vertraut.
# - Du bist mit den grundlegenden Datentypen vertraut.
# - Du kannst die `if/else`-Klausel verwenden.
# - Du kannst mit `for` und `while` über Listen iterieren.
# - Du bist mit dem Konzept von Klassen und Funktionen bekannt.

# %% [markdown]
# ## Teil 1: Die Programmiersprache Python
#
# Python ist eine von vielen Programmiersprachen, die verwendet werden können, um Programme zu schreiben. Heute ist Python die am weitesten gebräuchliche Programmiersprache weltweit. Gerade für komplette Neuanfänger ist sie beliebt, da der Code sehr intuitiv zu verstehen ist und Python viele Dinge implizit erledigt, die Benutzer bei anderen Sprachen selbst umsetzen müssen. Auch unter erfahrenen Benutzern hat Python den Vorteil, dass es schnell zu schreiben ist und eine grosse Zahl von externen Bibliotheken anbietet, wodurch man komplexe Prozesse nicht selbst programmieren muss. Insbesondere mit der Verbreitung von Machine-Learning-Applikationen hat Python an Beliebtheit gewonnen, da es einen einfachen Zugang zu diesen Technologien bietet. Die grösste Schwäche von Python, zumindest in gewissen Anwendungsbereichen, ist die Geschwindigkeit. Sprachen wie C sind erheblich schneller bei komplexen Berechnungen. Dieses Problem wird aber meist dadurch gelöst, dass z.B. eine Bibliothek für Machine Learning in C geschrieben ist, aber per Python verwendet werden kann.
#
# Python kann für verschiedenste Applikationen verwendet werden, zum Beispiel: Backend für Webapplikationen, Datenanalyse, Machine Learning, einfach mathematische Operationen, Textanalysen, Umgang und Umwandlung von Daten im Format von XML, JSON, etc. und viele mehr.
#
# Hier ein Beispielcode, zur Demonstration, wie intuitiv Python lesbar ist:

# %%
scores = [85.0, 90, 95, 65, 75]
total = sum(scores)
count = len(scores)
average = total / count
print("The average grade is:", average)

# %% [markdown]
# Im nächsten Teil gehe ich im Detail auf die hier verwendeten Datentypen ein, aber hier schon mal eine erste Erklärung:
#
# Der Code wird **von oben nach unten**, Zeile für Zeile, ausgeführt.
#
# Zuerst wird eine Liste erstellt (eckige Klammern), welche 5 Zahlenwerte enthält.
#
# Diese Liste wird dann einer sogenannten **Variable** zugewiesen, in diesem Fall "scores".
#
# Indem die Variable in die sogenannten **Funktionen** `sum()` und `len()` als **Parameter** gegeben wird, erhalten wir die Summe, resp. die Anzahl der Zahlenwerte in der Liste, und speichern diese wiederum unter neuen Variablennamen.
#
# Dann errechnen wir den Durchschnitt, indem wir die Variable, welche die Summe enthält, und die, welche die Anzahl Elemente enthält, verrechnen und das Ergebnis unter einer neuen Variable abspeichern.
#
# Schliesslich geben wir unser Ergebnis aus mithilfe einer `print()`-Funktion.
#
# Dieser Code könnte natürlich auch um einiges kürzer geschrieben werden:

# %%
scores = [85, 90, 95, 100, 75]
print("The average grade is:", sum(scores) / len(scores))
# Out:
# The average grade is: 89.0

# %% [markdown]
# ### Teil 1.1: Styleguide
# Es empfiehlt sich, aus Gründen der Übersichtlichkeit, den offiziellen Styleguide zu beachten: https://peps.python.org/pep-0008/
#
# Dieser erteilt Empfehlungen, wie z.B. Variablen benannt werden sollten oder ob Leerschläge zwischen Operatoren und Variablen gemacht werden sollten.
# Ihr müsst euch diesen Styleguide jetzt nicht durchlesen, kommt aber dazu zurück nachdem ihr dieses Dossier durchgearbeitet habt, und schaut ihn euch mal grob durch.

# %% [markdown]
# ### Teil 1.2: Hilfe, ich habe ein Problem!
#
# ![ein Meme](meme.jpg)
#
# Man könnte argumentieren, dass Googeln die wichtigste Fähigkeit einer jeden Programmier:in ist. Natürlich stimmt das nicht ganz, aber keine Programmierer:in weiss alles über Python und selbst grundlegende Codeblöcke wird man oft nachschlagen. Die wichtigsten Ressourcen, die euch begleiten werden, sind die folgenden:
#
# [Python Documentation](https://docs.python.org/3/)
#
# Die Python-Dokumentation ist absolut essentiell, gerade für Anfänger. Zu Beginn mag die Dokumentation überwältigend erscheinen, aber mehr Konzepte man versteht, desto einfach wird sie zu lesen sein. Ich möchte euch ermutigen, wann immer möglich bei Fragen erstmal mit der Dokumentation zu arbeiten und versuchen, die Antwort darin zu finden. Die Dokumentation enthält zahlreiche Code-Beispiele zur Anwendung aller Elemente der Standardbibliothek (der Teil von Python, der immer installiert ist mit Python zusammen). Ich werde Referenzen zur Dokumentation in den entsprechenden Abschnitten hinterlegen, so dass ihr die relevanten Teile schnell finden könnt.
#
# [Stackoverflow](https://stackoverflow.com/)
#
# Stackoverflow ist der Grund, wieso ProgrammiererInnen sich spasseshalber manchmal nur als Experten im copy&pasten von Code bezeichnen. Über Google findet man in diesem Frage-Antwort-Forum fast auf jede Frage zum Programmieren eine Antwort, egal ob es eine breite Frage zu den Grundlagen ist, oder eine extrem spezifische zu irgendwelchen externen Bibliotheken. Und wenn die Frage noch nie beantwortet wurde, kann man sie einfach stellen! Falls ihr Stackoverflow-Code verwendet, stellt immer sicher, dass ihr versteht, was der Code, den ihr kopiert habt, tut.
#
# [KI-Assistenz](https://github.com/features/copilot)
#
# In den Zeiten von ChatGPT kann man die KI-Assistenten nicht mehr weglassen in einer solchen Aufzählung. Das hier verlinkte Github-Copilot ist spezialisiert darauf, beim Programmieren zu helfen, während auch allgemeine Chatbots wie ChatGPT gut einfache Codeblöcke oder einfache Skripte schreiben können. Hier gilt aber natürlich, wie immer bei LLMs, dass sie gerne mal Fehler machen.
#
# [Externe Dokumentation](https://lxml.de/)
#
# Hier als Beispiel die Dokumentation der Bibliothek `lxml`, welche die Möglichkeiten im Umgang mit XML-Dateien erweitert. Bei externen Bibliotheken handelt es sich um Code-Pakete, die nicht zusammen mit Python auf eurem Gerät installiert werden. Man kann sie folgendermassen nutzen (Hier am Beispiel von lxml):

# %%
# Downloaden von lxml auf den PC über pip
# %pip install lxml

# Diese Form von Installation funktioniert nur in Notebooks.
# Ansonsten müsst ihr Module über das Terminal installieren (dasselbe Kommando nur ohne %)

# %%
# Importieren der Bibliothek für das entsprechende Skript
import lxml

print(lxml.__version__)

# %% [markdown]
# Man muss ein externes Paket nur einmal für ein Gerät, oder ein `environment`, falls ihr eines verwendet, installieren, man muss es aber für jedes Skript erneut importieren.
# Da der Import von Modulen (ein anderer Name für Bibliotheken) je nach Modul etwas Zeit kosten kann und auch Arbeitsspeicher belegt, empfiehlt es sich, immer nur Bibliotheken, die auch wirklich benötigt werden, zu importieren.

# %% [markdown]
# ## Teil 2: Grundlegende Datentypen
#
# Kommen wir zu den wichtigsten grundlegenden Konzepten. Es wichtig zu wissen, dass in Python jede Variable auf ein Objekt verweist (Wichtig, nur "verweist", denn mehrere Variablen können auf dasselbe Objekt verweisen). Jedes Objekt hat einen Datentyp. Wir haben im Beispiel von Teil 1 schon mehrere solche Datentypen kennengelernt: Zahlenwerte (`int` oder `float`), Listen (`list`) und Strings (`string`).
#
# Python weist Datentypen *implizit* zu, das heisst dass man dem Skript nicht explizit sagen muss, was für einen Datentyp eine Variable erhält.
#
# Aber sehen wir es uns an ein paar Beispielen an:

# %%
# Hashtags im Code stellen Kommentare dar

# Zahlenwerte
round_number = 5

decimal_number = 4.2

# Text / String
text = "Hallo Welt!"

# Logikwerte
true = True
false = False

# Listen
sequence = [round_number, decimal_number, text, true, false]

# Mit type() können wir den Datentyp (Klasse) des Objekts auf das die Variable verweist abfragen
print(type(round_number))

# %% [markdown]
# Teste in der folgenden Zelle mit type() die verschiedenen Variablen von oben auf ihre Typen. Variablen gelten immer für das ganze Notebook, du musst sie also nicht neu definieren. Du kannst zugewiesene Variablen in Visual Studio Code unter "Variables" nachsehen.

# %% [markdown]
# NoneType zeigt an, dass der Variable im Moment kein Objekt zugewiesen ist:

# %%
nothing = None

print(type(None))

# %% [markdown]
# Dass Python Datentypen implizit bestimmt, ist meistens sehr praktisch und beschleunigt den Prozess des Programmierens. Bei längerem Code kann es aber auch zu Verwirrung führen, aus diesem Grund bietet auch Python optional explizites `typing` an.

# %%
# Hashtags im Code stellen Kommentare dar

# Zahlenwerte (Integer oder Floats)
round_number = 5

decimal_number : float = 4.2

# Text (genannt Strings)
text : str = "Hallo Welt!"

# Logikwerte (Booleans)
true : bool = True
false : bool = False

# Listen
sequence : list = [round_number, decimal_number, text, true, false]

# Mit type() können wir den Datentyp (Klasse) des Objekts auf das die Variable verweist abfragen
print(type(round_number))

# %%
round_number

# %% [markdown]
# Der Vorteil von explizitem Typing ist einerseits Übersichtlichkeit, andererseits können gute Coding-Editoren durch explizites Typing schon vor Ausführen des Codes Fehler ausmachen und euch darauf hinweisen. Zum Beispiel wenn ihr versucht einen Datentyp an eine Funktion zu geben, die diesen Datentyp nicht verarbeiten kann. Viele Editoren können euch zudem den Datentyp der Variable durch darüberfahren anzeigen, was bei längerem Code sehr wertvoll sein kann.
#
# An diesem Punkt ist euch vielleicht schon aufgefallen, dass wir Variablen mehrmals definieren (da die Variablen ja über alle Zellen geteilt werden). Für Python bedeutet das einfach, dass die Variable dann auf das neue Objekt verweist. Verweist keine Variable oder Attribut (zu denen kommen wir später) mehr auf ein Objekt, dann räumt Python es automatisch auf, macht also den Speicherplatz wieder frei

# %% [markdown]
# #### Exkurs: Funktionen in Kürze
#
# Ich möchte hier kurz auf das Konzept von Funktionen eingehen:
#
# Ihr habt nun schon einige Funktionen kennengelernt, z.B. `print()` oder `type()`. Bei diesen beiden handelt es sich um [Built-In Funktionen](https://docs.python.org/3/library/functions.html). Ihr werdet auch Funktionen sehen, die von einem Objekt aus aufgerufen werden, wie später `list.append()`, das Objekte zu Listen hinzufügt. Jedes Objekt hat Funktionen, die durch seinen Datentyp definiert werden. Manche Funktionen sind spezifisch für den Datentyp, zum Beispiel `append()` bei Listen. Die Built-In Funktionen hingegen rufen bei den Klassen der Objekte die sogenannten "magischen Methoden" oder Attribute auf, die sich viele Datentypen teilen. Zum Beispiel ruft `type()` das `__class__`-Attribut des Objekts auf und gibt den Wert davon zurück.
#
# Wie ihr seht, zeichnen sich Funktionen durch die Runden Klammern aus (Vorsicht, sie werden auch für andere Zwecke benutzt). Je nach Funktion können durch die runden Klammern sogenannte "Argumente" mitgegeben werden. Manche, aber nicht alle Funktionen haben einen `return`-Wert der zurückgegeben wird. `print()` zum Beispiel hat keinen `return`-Wert, bzw. einen Wert von `None`. `type()` hingegen hat einen `return`-Wert, es gibt ein Objekt vom Datentyp `type` zurück. Hat eine Funktion einen `return`-Wert, können wir den Wert einer Variable zuweisen, wie schon in den obigen Beispielen. Beachte, dass viele Funktionen mehrere Argumente annehmen können, wobei manchmal Argumente auch *optional* sind, ihnen ist in dem Fall ein `default`-Wert zugeschrieben, der aber überschrieben werden kann.
#
# Im letzten Teil dieses Dossiers sehen wir uns noch an, wie wir selbst Funktionen schreiben können.

# %% [markdown]
# ### Teil 2.1: Zahlenwerte
#
# Mit Integern (Ganze Zahlen) und Floats (Dezimal-Zahlen) können wir alles Mathematische in Python regeln. Python wandelt Integer-Objekte implizit in Float-Objekte um, wenn es nötig ist. Die meisten mathematischen Operatoren dürften euch bekannt sein, ansonsten konsultiert die [Dokumentation](https://docs.python.org/3/library/stdtypes.html#numeric-types-int-float-complex). Ihr werdet darin ausserdem sehen, dass es eigentlich noch ein paar weitere numerische Datentypen gibt, aber mit allerhöchster Wahrscheinlichkeit werdet ihr niemals mit diesen zu tun haben. Im Folgenden ein Beispiel zu die üblichsten Operationen:

# %%
x = 9
y = 4

# Addition / Subtraktion
sum = x + y
diff = x - y

# Multiplikation / Division
prod = x * y
frac = x / y

# Exponentierung (x hoch y)
pow = x ** y

# Rest
mod = x % y

# Negation
neg_x = -x
neg_y = -y

# Betrag
abs_x = abs(neg_x)


# Modifiziere diese print()-Funktion um dir die Resultate anzusehen
print(abs_x)

# Und überprüfe auch den Typ!
print(type(abs_x))

# %% [markdown]
# Alle obigen Funktionen sind mit Integern und Floats verwendbar. Hinter den Kulissen sind die mathematischen Operatoren in Python übrigens auch nur Funktionen in Kurzform:

# %%
# Addition
sum = x.__add__(y)

print(sum)

# %% [markdown]
# Wenn man also `x + y` schreibt, dann ruft man eigentlich die Funktion `__add__()` des Objekts x und gibt als Argument y.
#
# Dir dürfte auch aufgefallen sein, dass das Resultat der Division unter der Variable `frac` kein Integer mehr ist, sondern ein Float. Dies geschieht auch, wenn die Division eine ganze Zahl ergibt, die eigentlich als Integer dargestellt werden könnte.
#
# Ein Float bleibt übrigens ein Float, ausser man wandelt ihn explizit in einen Integer um:

# %%
print("Original:", frac)
back_to_round = round(frac)

print("Nach der Rundung:", back_to_round)
print("Typ:", type(back_to_round))

# %% [markdown]
# Bei der `round()`-Funktion handelt es sich um eine sogenannte [Built-in Funktion](https://docs.python.org/3/library/functions.html) (Wie auch `print()`!). Sie steuert eine eingebaute Methode im Objekt an, und führt einen entsprechenden Prozess aus, in diesem Fall rundet sie die Zahl und wandelt sie in einen Integer um.
#
# Mini-Aufgabe:
#
# Funktionen können verschiedene Mengen an Argumenten akzeptieren. [print()](https://docs.python.org/3/library/functions.html#print) zum Beispiel akzeptiert eine beliebige Anzahl an Objekten als Argumente (sie werden dann einfach durch Leerschläge getrennt ausgegeben) und eine ganze Reihe von optionalen Argumenten, wie zum Beispiel das Trennsymbol zwischen den Objekten (per default Leerschlag) oder einem Zeichen das an jeden Output angehängt wird (per default ein Zeilenumbruch, `/n`). Auch `round()` hat ein optionales Argument `ndigits`. Finde mithilfe der Dokumentation heraus, wozu dieses Argument dient und teste es in der Zelle oben.

# %% [markdown]
# ### Teil 2.2: Wahrheitswerte
#
# Die sogenannten Boolean-Objekte sind essentiell für den meisten Code. Diese Objekte enthalten immer entweder den Wert `True` oder `False`. Andere Datentypen erzeugen oft durch ihre Funktionen Boolean-Objekte, zum Beispiel beim Vergleich von Zahlenwerten:

# %%
x = 5
y = 3

smaller = x < y

# ist x kleiner als y?
print(smaller)

# %% [markdown]
# Im Teil zu den `if/else`-Statements werde ich weitere Logikoperanden vorstellen, viele davon dürften Dir schon bekannt sein.
#
# Man kann alle Objekte auch explizit in Boolean-Objekte umwandeln durch `bool()`:

# %%
print(bool(42))

print(bool(0))

# %% [markdown]
# Jedes Objekt definiert über seine `__bool__`-Methode selbst, wann es True und False zurückgibt, wenn es implizit oder explizit als Wahrheitswert verwendet wird. Zahlenwerte zum Beispiel geben `False` zurück, wenn der Zahlenwert 0 beträgt, ansonsten `True`. Strings geben nur dann `False` zurück, wenn keine Zeichen im String enthalten sind. Listen, wenn keine Elemente in der Liste enthalten sind. Diese Zustände sind nicht zu verwechseln mit `None`, denn die Objekte existieren, sie sind nur leer (Wobei eine `None`-Variable auch implizit einen Wahrheitswert von `False` zurückgibt).

# %% [markdown]
# ### Teil 2.3: Strings
#
# Text wird in Python in Form von sogenannten String-Objekten repräsentiert. Durch `"` oder `'` werden Strings definiert und Variablen zugewiesen. Ihr könnt eines der beiden Zeichen verwenden, aber es ist unschön, es innerhalb desselben Codes zu mischen.
#
# Da Strings Sequenzen von Zeichen sind, teilen sie viele mögliche Operationen mit Listen, die ich dort weiter erläutern werde. Strings bringen Funktionen mit, die schnelle Manipulation von Texten ermöglichen:

# %%
text = "Es ist so toll an der Zentralbibliothek Zürich programmieren zu lernen!"
text2 = "Ich liebe Python!"

# Gross- / Kleinschreibung
uppercase = text.upper()
lowercase = text.lower()
is_uppercase = text.isupper()
is_lowercase = text.islower()

# Entfernen von Zeichen, z.b. Satzendungen
clean = text.rstrip("!")
clean = text.replace("e", "")
print("Text ohne e:", clean)

# Umwandlung vom String in eine Liste von Wörtern
words = text.split()
print("Text als in Worteinheiten:", words)

# Verbinden von Strings zu längeren Strings
long_text = text + " " + text2
print("Text zusammengenommen:", words)

# %% [markdown]
# Mehr String-Operationen und Informationen findest du in der [Dokumentation](https://docs.python.org/3/library/stdtypes.html#text-sequence-type-str)
#
# Im obigen Beispiel wirst Du entdecken, dass einige der Resultate, zum Beispiel von `split()` und `isupper()` andere Datentypen als Strings erzeugen. Hast du herausgefunden, was der Unterschied zwischen `isupper()` und `upper()` ist?

# %% [markdown]
# #### Exkurs: Unveränderliche Objekte und das Überschreiben von Variablen
#
# Bei den bisher besprochenen Datentypen handelt es sich um unveränderliche Objekte. Ein Beispiel demonstriert diese Eigenschaft gut:

# %%
text = "Hallo Welt!"
text.lower()

print(text)

# %% [markdown]
# Das Objekt, auf das die Variable `text` verweist, ist nicht verändert worden durch die Anwendung der Funktion `lower()`!

# %%
text = "Hallo Welt!"
text = text.lower()

print(text)

# %% [markdown]
# Was ist der Unterschied? Wir mussten das Resultat der `lower()`-Funktion erneut der Variable zuweisen um die alte Zuweisung zu überschreiben. Ist ein Integer, Float oder String erstmal definiert, ist es *unveränderlich*, das heisst wir können das Objekt nicht weiter modifizieren, aber wir können die Variable, die darauf verweist, überschreiben mit dem neuen Wert. Auch bei Zahlenwerten können wir das tun:

# %%
number = 0

number = number + 1
# alternative Schreibweise:
number += 1

print(number)

# %% [markdown]
# #### Exkurs: String-Formatting
#
# Wir können Werte von anderen Objekte sehr einfach in Strings einbauen, in dem wir eine Formatting-Methode verwenden. Vergleiche im nächsten Code-Block die drei Ansätze:

# %%
age = 42

# String-Concatenation
text1 = "Ich werde bald " + str(age) + " Jahre alt!"
# F-String-Formatting
text2 = f"Ich werde bald {age} Jahre alt!"
# Format-Methode
text3 = "Ich werde bald {0} Jahre alt!".format(age)

print(text1)
print(text2)
print(text3)

# %% [markdown]
# Die zweite Methode, [f-Strings](https://docs.python.org/3/reference/lexical_analysis.html#f-strings), finden heute am meisten Gebrauch, da sie kurz und intuitiv sind. Sie bieten wie auch die `format`-Methode Möglichkeiten, das gegebene Objekt noch zu modifizieren. Im Falle von Zahlenwerten z.B. noch ein Padding durchzuführen:

# %%
age = 42
text = f"Ich werde bald {age:04d} Jahre alt!"

print(text)

# %% [markdown]
# ### Teil 2.4: Listen
#
# Listen sind Objekte, die eine Sequenz von Objekten enthalten. Es gibt dabei keine Restriktionen wie viele Elemente sie enthalten dürfen, oder was für Datentypen die Elemente haben.
#
# Listen sind wie Strings iterierbare Objekte, was es möglich macht, bestimmte Operationen auf ihnen auszuführen.
#
# Im Gegensatz zu Strings sind Listen aber *veränderliche* Objekte, das heisst es gibt Funktionen, mit denen wir Listen verändern können und nicht jedes Mal ein neues Objekt erstellt werden muss. Wir nennen solche Funktionen auch *in-place* Funktionen. In-Place-Funktionen haben keinen `return`-Wert. Manche Manipulationen, zum Beispiel das Sortieren von Listen, kann *in-place* oder auch nicht erfolgen, je nach gewählter Funktion. Möchte man z.B. die unsortierte Liste erhalten, sollte man nicht in-place sortieren, sondern das Resultat der Sortier-Funktion einer neuen Variable zuweisen.

# %%
# Eine Liste kann mit oder ohne Inhalt erstellt werden
empty = []
filled = [6, 8, 4, 5, -1]

# Elemente hinzufügen
empty.append(42)

# Elemente entfernen
filled.remove(8)
empty.clear()

# Liste umdrehen
filled.reverse()

# Liste sortieren
filled.sort()
print(filled)

# Wie viele Elemente hat die Liste?
print(len(filled))

# %% [markdown]
# Die obigen Funktionen sind alle in-place Funktionen und können von Strings nicht genutzt werden. Beachte, dass wir jeweils keine neuen Variablen zuweisen müssen!
# Es gibt aber für das Umdrehen und das Sortieren Alternativen, die sowohl auf Strings, wie auch auf Listen ausführbar sind:

# %%
text = "Hallo Welt!"
# wir können aus dem Text eine Liste machen mit list(), wobei dann jedes Zeichen als ein Element abgebildet wird
# nicht zu verwechseln mit split()!

sorted_text = sorted(text)

rev_text = reversed(text)

print(sorted_text)
print(rev_text)

# %% [markdown]
# Zuerst zu dem sortierten Text. Die `sorted()`-Funktion erzeugt immer Listen, also müssen wir das Objekt wieder in einen String umwandeln. Dies tun wir mit diesem nicht ganz intuitiven Code:

# %%
back_to_string = " ".join(sorted_text)

print(back_to_string)

# %% [markdown]
# Die `join()`-Funktion gehört zur String-Klasse, kann also von String-Objekten aufgerufen werden. Sie nimmt eine Liste als Argument entgegen und konstruiert dann einen String, bei dem alle Listenobjekte mit dem gegebeen String verbunden werden, im obigen Beispiel ein Leerschlag.
#
# Nun zu dem `reversed object`; Hierbei handelt es sich um ein [Iterator](https://docs.python.org/3/glossary.html#term-iterator)-Objekt. Diese sind etwas zu kompliziert zu erklären im Moment, aber es sollte genügen zu sagen, dass sie in erster Linie zur Effizienz dienen und sie können nur iteriert (z.B. mit einer `for`-Schleife, wie später erklärt) werden, nicht andersweitig manipuliert oder ausgelesen. Wir können diese ganz einfach umwandeln in Listen oder direkt in Strings:

# %%
rev_text_as_string = " ".join(rev_text)
rev_text_as_list = list(rev_text)

print(rev_text_as_string)
print(rev_text_as_list)  # kommt leer heraus weil Iteratoren sich leeren, wenn sie aufgerufen werden

# %% [markdown]
# #### Teil 2.5: Indices und Slicing
#
# Listen und Strings können beide von Slicing Gebrauch machen und per Indices auf ihre Elemente zugreifen. Nicht alle iterierbaren Objekte bieten die folgenden Funktionalitäten, nur sogenannte [Sequence-Types](https://docs.python.org/3/library/stdtypes.html#typesseq).
#
# Jedes Element steht an einem bestimmten Index in der Sequenz. Das erste Element hat immer Index 0, das zweite 1, das dritte 2 und so weiter.
#
# Wir können den Index eines Elements im String abfragen:

# %%
text = "Hallo Welt!"
idx = text.index("l")

print(idx)

# %% [markdown]
# Bemerke, dass nur der Index für das zuerst gefundene Element zurückgegeben wurde! Bei Strings können wir übrigens auch ganze Substrings suchen, die aus mehreren Zeichen bestehen:

# %%
text = "Hallo Welt!"
idx = text.index("lo")

print(idx)

# %% [markdown]
# Wenn uns übrigens der Index nicht interessiert und wir nur prüfen wollen, ob der Substring bzw. das Element in der Sequenz enthalten ist, benutzen wir den (schnelleren) `in`-Operator:

# %%
hit = "lo" in "Hallo Welt!"

print(hit)

# %% [markdown]
# Nun aber zurück dazu, was wir mit den Indizes anfangen können. Sie ermöglichen es uns, Elemente in einer Sequenz (wie einer Liste oder einem String) per Index auszuwählen, aber auch gewisse Teile der Sequenz in einem von-bis System zu erhalten.
#
# Der Doppelpunkt dient in diesem Fall als Symbol für das von bis: 0:5 heisst also vom ersten Element bis und mit dem fünften Element.

# %%
first_element = text[0]

# Wir können auch von hinten zählen, mit -1 erhalten wir das letzte Element
last_element = text[-1]

# Einen Substring auslesen
substring = text[0:3]
# Wir können die 0 auch weglassen:
substring = text[:3]

# Wenn wir von einem Index bis zum Ende der Sequenz auslesen wollen:
suffix = text[6:]

# Wollen wir also an einem bestimmten Index einen Satz teilen, können wir es folgendermassen tun:
index = 9
sentence = "Das hier ist ein Satz, der geschnitten wird."
first_part = sentence[:index]
second_part = sentence[index:]

print(first_part)
print(second_part)

# %% [markdown]
# ### Lernkontrolle:

# %%
# Ein paar Variablen
a = 5
b = 2.0
c = "hello"
d = [1, 2, 3]

# Integer und Floats
# ----------------------------------------------
# 1. Addiere a und b und weise das Resultat der Variable "sum" zu.
# 2. Teile a durch b und weise das Resultat der Variable "frac" zu.
# 3. Multipliziere b mit 3 und weise das Resultat der Variable "prod" zu.

# Strings
# -----------------------------------
# 1. Füge den String "world" an der Variable c an und weise das Resultat der Variable "text" zu.
# 2. Wiederhole c 3 mal und weise das Resultat der Variable "repeat" zu.

# Lists
# ---------------------------------
# 1. Füge der Liste d einen Integer mit Wert 4 hinzu.
# 2. Greife auf das zweite Element in d zu und weise ihn der Variable "element" zu.
# 3. Erstelle eine neue Liste, die nur das zweite und dritte Element von d enthält und weise sie einer Variable "shortlist" zu.

# %% [markdown]
# Du findest Musterlösungen zu den Lernkontrollen im selben Ordner wie das Dossier.

# %% [markdown]
# ## Teil 3: `if` und `else`: Kontrolle über den Flow
#
# Die Anwendung der `if` und `else`-Klauseln sollte recht intuitiv sein: Die `if`-Klausel verlangt eine Bedingung, wird diese erfüllt (evaluiert zu `True`), wird der eingeschobene Code darunter ausgeführt, ansonsten wird dieser Code ignoriert. Ist eine `else`-Klausel vorhanden, wird diese stattdessen ausgeführt. Im Folgenden ein Anwendungsbeispiel:

# %%
number = 42
divider = 4
rest = number % divider

# Erinnere Dich daran wie Integer zu Boolean umgewandelt werden um zu verstehen wann rest hier die Bedingung erfüllt
if rest:
    print(f"The number {number} cannot cleanly be divided by {divider}!")
else:
    print(f"The number {number} can cleanly be divided by {divider}!")

# %% [markdown]
# Wie schon erwähnt ist die `else`-Klausel hier optional.
#
# Bemerkt die Einschübe: Sie werden mit der Tabulator-Tase verursacht und jeder gute Editor wird dadurch 4 Leerzeichen abbilden, wobei auch ein Tabulator für Python funktioniert, man kann es aber nicht mischen (4 Leerzeichen werden empfohlen). Python verwendet die Einschübe um darzustellen, von wo bis wo der Code steht, der durch eine Klausel wie `if` und `else` ausgeführt wird. An einem weiteren Beispiel:

# %%
wrong = False

if wrong:
    # Beginn der if-Klausel
    print("This shouldn't be executed.")
    # Ende der if-Klausel

# Zurück ausserhalb der Klausel
print("This gets executed in any case.")

# %% [markdown]
# Wie zu sehen ist, wird das zweite `print`-Statement, das nicht eingeschoben wurde, in jedem Fall, unabhängig des Resultats der `if`-Klausel ausgeführt wird. Leere Zeilen sind übrigens irrelevant für Python, es gibt aber Empfehlungen im Styleguide wann und wo leere Zeilen eingeschoben werden sollten, diese dienen der Lesbarkeit des Codes. Wenn wir mehrere `if` oder `else`-Statements verschachteln, müssen wir mehrere Einschübe machen:

# %%
right = True
wrong = False

if right:
    
    if wrong:
        print("This shouldn't be executed.")

    print("But this will be executed.")

print("This gets executed in any case.")

# %% [markdown]
# Es gibt keine Einschränkung, wie viele `if-else`-Statements man verschachteln kann, aber der Lesbarkeit halber sollte man sich damit zurückhalten. Dank selbstgeschriebenen Funktionen (kommt später im Detail) und `elif` brauchen wir normalerweise keine komplizierten Baumstrukturen. `elif` wird geprüft, wenn `if` oder das vorherige `elif` falsch evaluieren und ausgeführt, wenn die Bedingung zu `True` evaluiert.

# %%
animal = "lion"

if animal == "insect":
    print("It's an insect!")
elif animal == "horse":
    print("It's a horse!")
elif animal == "lion":
    print("It's a lion!")
else:
    print("I don't know which animal it is.")

# Update mit Python 3.10 und neuer: Hier gibt es für Fälle wie im obigen Beispiel den match-case-Syntax als Abkürzung.

# %% [markdown]
# Im obigen Beispiel benutze ich auch schon den ersten Logikoperator, kommen wir also nun zu diesem wichtigen Instrument.

# %% [markdown]
# ### Teil 3.1: Logikoperatoren
#
# Wir können Objekte mittels verschiedener [Vergleichsoperatoren](https://docs.python.org/3/library/stdtypes.html#comparisons) miteinander vergleichen. Unter dem Deckel funktionieren diese als Funktionen der jeweiligen Objekte, denen das oder die anderen Objekte als Argumente gegeben werden. Folgende Methoden haben wir, um Objekte zu vergleichen:
#
# - Ist-gleich: `==`
# - Grösser-als: `>`
# - Kleiner-als: `<`
# - Grösser-gleich-als: `>=`
# - Kleiner-gleich-als: `=<`
# - Nicht-gleich: `!=`
#
# Etwas speziell ist noch `is` und `is not`, die vergleichen, ob es sich um dasselbe Objekt handelt. Vergleiche dazu den folgenden Code:

# %%
list1 = ["A", "B", "C"]
list2 = ["A", "B", "C"]

print(list1 == list2)
print(list1 is list2)

# Aber:
list3 = list1
print(list1 is list3)

# %% [markdown]
# Wir haben auch schon einige andere Funktionen kennengelernt, die einen Boolean-Wert erzeugen und dadurch für Bedingungen genutzt werden können, wie `islower()` bei Strings oder der `in`-Operator, der prüft ob ein Wert in einer Sequenz enthalten ist.
#
# Komplexere Bedingungen können wir mittels sogenannter [Boolean-Operationen](https://docs.python.org/3/library/stdtypes.html#boolean-operations-and-or-not) formulieren: `and`, `or` und `not`.
#
# `and` evaluiert `True` wenn beide Werte `True` sind, `or` wenn mindestens einer `True` ist und `not` kehrt den Wahrheitswert um, evaluiert also `False` bei `True` und `True` bei `False`. Um zu zeigen, welche Bedingungen zuerst evaluiert werden sollen, müssen wir Klammern verwenden. Probiere beim folgenden Codebeispiel aus, wie sich der Output je nachdem verändert, was in Zeilen 6-8 den Variablen zugewiesen wird.

# %%
# Simulieren wir ein einfaches Login-Verfahren
correct_username = "HelloWorld"
correct_password = "hunter12"

# Wenn der Superuser aktiv ist, loggen wir immer ein, egalb ob username und passwort stimmen.
superadmin_rights_active = True
given_username = "HelloWorld"
given_password = "oefughweiufg"

if superadmin_rights_active or (correct_username == given_username and correct_password == given_password):
    print("Login accepted!")
elif correct_username == given_username:
    print("Password incorrect!")
else:
    print("Username not recognized.")

# %% [markdown]
# Es wird übrigens immer erst die Bedingung links von einem `and` oder `or` geprüft, dann rechts. Bei einem `and` wird auf die Prüfung der rechten Bedingung verzichtet, wenn die Linke schon `False` evaluiert. Dies kann relevant sein in zum Beispiel einem solchen Fall:

# %%
sentence1 = "Hier an der ZB Zürich lernen wir Python .".split()
sentence2 = "Hallo zusammen!".split()

if len(sentence2) > 3 and sentence2[3] == "ZB":
    print("Yep.")
elif len(sentence2) <= 3:
    print("Der Satz ist zu kurz :-(")

# %% [markdown]
# Würden wir nicht zuerst prüfen, dass `sentence` mindestens 4 Elemente enthält, wir aber dann versuchen auf das Objekt bei Index 3 zuzugreifen, dieser aber nicht existiert, weil die Liste kürzer ist als 4, werden wir eine Fehlermeldung erhalten (Probiert es ruhig aus).
#
# Dir ist vielleicht schon aufgefallen, dass wir die Vergleichsoperatoren nicht nur mit Zahlenwerten verwenden können, sondern auch z.B. zwischen Strings. Auf welche Weise werden diese verglichen? Findest du es bei Listen heraus?

# %%
print("A" > "Z")

print([1,2,3] < [3,2,1])

# %%
sorted(["Z", "A", "a", "b", "1", "3", "!", "😊"])

print("😊".encode("utf8"))

# %% [markdown]
# ### Lernkontrolle:

# %%
#Definieren einer Variable
# ----------------------------------
# Definiere eine Variable namens "age" und weise ihr einen Integer-Wert zu.

# Schreiben einer If-Else-Klausel
# -----------------------------------------
# Schreibe eine If-Else-Klausel, um zu überprüfen, ob das Alter grösser oder gleich 18 ist.
# Falls ja, gib "Du bist volljährig" aus.
# Andernfalls gib "Du bist minderjährig" aus.

# Hinzufügen einer zusätzlichen Bedingung
# -----------------------------------------------
# Ändere die If-Else-Anweisung so, dass sie prüft, ob das Alter genau 18 ist.
# Falls ja, gib "Du bist gerade 18 geworden!" zusätzlich zu den vorherigen Ausgaben aus.

# Verschachtelte Bedingungen hinzufügen
# ---------------------------------------------
# Ändere die If-Else-Anweisung so, dass sie eine weitere Bedingung enthält.
# Wenn das Alter größer oder gleich 65 ist, gib "Du bist ein Senior".
# Wenn das Alter zwischen 18 und 64 (einschließlich) liegt, gib "Du bist im arbeitsfähigen Alter".
# Wenn das Alter unter 18 liegt, gib "Du bist minderjährig" aus.

# Testen mit verschiedenen Altersangaben
# ----------------------------------------------
# Teste den Code, indem du verschiedene Werte der `age`-Variable zuweist und die Ausgabe beobachtest.

# Beispiel-Ausgabe
# ----------------
# Wenn Alter 17 ist: Du bist minderjährig
# Wenn Alter 18 ist: Du bist im arbeitsfähigen Alter
# Wenn Alter 65 ist: Du bist ein Senior
# Wenn Alter 70 ist: Du bist ein Senior

# %% [markdown]
# ## Teil 4: Schleifen
#
# Ein wichtiges Werkzeug für jeden Programmierer sind Schleifen. Die gebräuchlichste Variante davon in Python ist die `for`-Schleife. Sie kann intuitiv gelesen werden als "for element in sequence do etc.".
#
# Im folgenden ein Anwendungsbeispiel:

# %%
sentence = "Hier in Zürich lernen wir Python !".split()

for word in sentence:
    if word[0].isupper():
        print("Grossgeschrieben.")
    else:
        print("Kleingeschrieben.")

# %% [markdown]
# Wir nutzen erneut die Einschübe um den Fluss des Codes zu kontrollieren. Wir gehen jedes Element durch, in diesem Fall jedes Wort des Satzes, den wir an den Leerschlägen getrennt haben, und untersuchen es auf einfache Weise in diesem Fall.
#
# Bei `word` handelt es sich hierbei um eine neue Variable, die bei jeder Iteration neu zugewiesen wird, nämlich immer dem nächsten Element der Sequenz. Wir haben bis jetzt zwei Datentypen kennengelernt, die iteriert werden können: Strings und Listen. In den folgenden Dossiers werden noch ein paar dazukommen.
#
# Wir können Schleifen natürlich auch wieder verschachteln:

# %%
sentence = "Hier in Zürich lernen wir Python !".split()

for word in sentence:
    for character in word:
        if character.lower() >= "p":
            # Buchstaben, die nach p im Alphabet kommen
            print(character)

# %% [markdown]
# Das ist eigentlich auch schon das meiste, was man zu Schleifen wissen muss. In 90% der Fälle wird eine `for`-Schliefe das beste Werkzeug sein, um eine Iteration durchzuführen.
# Es gibt aber noch ein paar Fälle, in denen man zu einer `while`-Schleife greifen möchte:

# %%
sentence = "Hier in Zürich lernen wir Python !".split()
index = 0

while index < len(sentence):
    word = sentence[index]

    for character in word:
        if character >= "p":
            print(character)

    index += 1

# %% [markdown]
# Eine `while`-Schleife läuft so lange, bis die Bedingung zu `False` evaluiert. In diesem Fall ist das dann, wenn der `index` eine Zahl angibt, die länger wäre als die verfügbaren Indices des Satzes. Der obige Code ist als for-Schleife sicher einfacher zu schreiben, wann also `while` verwenden? `while`-Schleifen können praktisch sein, wenn man zum Beispiel nicht im Voraus weiss, wie oft man iterieren muss oder möchte.
#
# Zum Beispiel, wenn wir uns in einer XML-Baumstruktur befinden, und alle Eltern-Elemente eines gegebenen Elements untersuchen wollen bis wir eine bestimmte Eigenschaft antreffen. Bei `while`-Schleifen ist es wichtig zu überprüfen, dass keine unendlichen-Schleifen entstehen und die Abbruchbedingung immer nach einer Weile eintritt, in diesem Fall spätestens, wenn wir die root-Node "XML" finden:

# %%
# Der Code in dieser Spalte ist nicht funktional, weil wir an dieser Stelle keinen ganzen XML-Baum laden
# er soll nur der Demonstration einer sinnvollen Anwendung einer "while"-Schlaufe dienen
# (wobei man das hier sicher auch mit einer XQUERY lösen könnte ;-) )

def get_parent_with_tag(given_node, tag):
    # die Schlaufe findet in einer Funktion statt
    # given_node ist die Variable, die den gegebenen XML-Knoten enthält
    # tag ist der tag, den das gesuchte Ancestor-Element haben soll
    parent = given_node.parent()  # .parent() gibt das Elternelement zurück
    while parent.tag != "XML" and parent.tag != tag:
        parent = parent.parent()
    return parent

# %% [markdown]
# Ein weiteres Hilfsmittel, das man kennen sollte, sind `range` und `enumerate`:

# %%
sentence = "Hier in Zürich lernen wir Python !".split()

for index in range(0, len(sentence), 2):
    word = sentence[index]
    print(word)

for index, word in enumerate(sentence):
    print(index, word)

# %%
sentence = "Hier in Zürich lernen wir Python !".split()

for element in enumerate(sentence):
    print(element)

# %% [markdown]
# Mit `range()` erstellen wir einen Iterator, der Integers vom ersten Wert bis zum letzten Wert (exklusive den letzten Wert) ausgibt. Es ist eine praktische Funktion um schnell Zahlenreihen zu generieren, da man auch Schritte als Argumente angeben kann, z.B. 10, 20, 30, 40, 50 zurückzugeben. Siehe dazu mehr in der [Dokumentation](https://docs.python.org/3/library/stdtypes.html#range).
#
# Mit `enumerate()` erhalten wir einen Iterator, der sowohl die Elemente der Sequenz selbst ausgibt, wie auch deren Indices. Wir sehen hier ausserdem, dass wir mehrere Variablen gleichzeitig zur Iteration nutzen können. Um das kurz ausführlicher darzustellen:

# %%
data = [
    ["Max", 26],
    ["Lena", 13],
    ["Anna", 45],
    ["Theo", 9]
]

for name, age in data:
    if age >= 18:
        print(f"{name} needs a ticket for adults.")
    else:
        print(f"{name} gets a cost reduction for children.")

# %% [markdown]
# Alternativ könnte man die Schleife etwas anders schreiben:

# %%
for person in data:
    # wir können das unpacking auch auf einer separaten Zeile machen
    name, age = person
    # oder, noch expliziter
    name = person[0]
    age = person[1]
    if age >= 18:
        print(f"{name} needs a ticket for adults.")
    else:
        print(f"{name} gets a cost reduction for children.")

# %% [markdown]
# Diese Art des "Unpackings" erfordert aber, dass der Datensatz konsistent zwei Objekte pro Unterliste enthält. Teste mal was passiert, wenn Du bei einer der Unterlisten ein Element hinzufügst oder wegnimmt, z.B. `["Max", 16, "m"]`.
#
# Wir können diese Techniken auch noch weiter verschachteln, in diesem Beispiel benutze ich `enumerate()`:

# %%
data = [
    ["Max", 26],
    ["Lena", 13],
    ["Anna", 45],
    ["Theo", 9]
]

for index, (name, age) in enumerate(data):
    if age >= 18:
        print(f"Passenger {index}: {name} needs an ticket for adults.")
    else:
        print(f"Passenger {index}: {name} gets a cost reduction for children.")

# %% [markdown]
# Bemerke hier die Klammern, die erforderliche sind für das erfolgreiche "Unpacking".

# %% [markdown]
# ### Teil 4.1: `break`, `continue` und `pass`
#
# Mit diesen Statements können wir das Verhalten von Schleifen weiter kontrollieren:
# * `break` beendet die laufende Schleife sofort
# * `continue` überspringt den Rest des Codes bei dieser Iteration und geht sofort zum nächsten Element
# * `pass` dient als Platzhalter, meistens wird er verwendet, wenn später dort noch Code hinkommt.
#
# Ein Beispiel:

# %%
data = [
    ["Max", 26],
    ["Lena", 13],
    ["Anna", 45],
    ["Theo", 9]
]

for name, age in data:
    
    if name == "Max":
        print(name)
        continue  # überspringen

    if name == "Lena":
        print(name)
        pass

    if name == "Anna":
        print(name)
        break  # Beenden der Schleife!

    print(name)

# %% [markdown]
# Noch ein kleiner Trick: Auch Schleifen haben eine `else`-Klausel. Sie wird ausgeführt wenn eine Schleife *nicht* durch ein `break`-Statement endet (also entweder weil bei einer `for`-Schleife das letzte Element gelesen oder bei einer `while`-Schleife die Bedingung `False` war).

# %%
data = [
    ["Max", 26],
    ["Lena", 13],
    ["Anna", 45],
    ["Theo", 9]
]

for name, age in data:
    if name == "Max":
        continue  # überspringen

    if name == "Lena":
        pass  # TODO

    if name == "STOP":
        break  # Beenden der Schleife!

    print(name)
else:
    print("Loop executed successfully!")

# %% [markdown]
# ### Teil 4.2: Listenkomprehension
#
# Wir können Schleifen auch sehr kompakt schreiben, und diese Schreibweise ist sogar effizienter in der Berechnung.
#
# Hier ein Beispiel, wie Listenkomprehension einfach benutzt werden kann, um jedes Element in einer Liste zu manipulieren:

# %%
sentence = "Hier in Zürich lernen wir Python !".split()

# Hier eine ausgeschriebene Schleife
lower_words = []
for word in sentence:
    lower_words.append(word.lower())

# Als Listenkomprehension:
lower_words = [word.lower() for word in sentence]

print(lower_words)

# %% [markdown]
# Im nächsten Beispiel zeige ich, wie Listenkomprehension genutzt werden kann um eine Liste zu filtern:

# %%
sentence = "Hier in Zürich lernen wir Python !".split()

# Hier eine ausgeschriebene Schleife
upper_words = []
for word in sentence:
    if word[0].isupper():
        upper_words.append(word)

# Als Listenkomprehension:
upper_words = [word for word in sentence if word[0].isupper()]

print(upper_words)

# %% [markdown]
# Wir können sogar noch eine `else`-Klausel hinzufügen (Vorsicht, das `if` wird dann an einen anderen Ort gesetzt!):

# %%
sentence = "Hier in Zürich lernen wir Python !".split()

# Hier eine ausgeschriebene Schleife
upper_words = []
for word in sentence:
    if word[0].isupper():
        upper_words.append(word)
    else:
        upper_words.append(0)

# Als Listenkomprehension:
upper_words = [word if word[0].isupper() else 0 for word in sentence]

print(upper_words)

# %% [markdown]
# Listenkomprehensionen sind auch sehr praktisch um verschachtelte Listen zu organisieren:

# %%
data = [
    ["Max", 26],
    ["Lena", 27],
    ["Anna", 45],
    ["Theo", 9]
]

# Wir wollen nur noch die Personennamen:
names = []
for name, age in data:
    names.append(name)

# Als Listenkomprehension
names = [name for name, _ in data]  
# das Unpacking erfordert, dass wir zwei Variablen definieren, 
# weil wir aber nur den Namen verwenden setzen wir laut Konvention den anderen Variablennamen auf _ 
# Dies dient keinem technischem Zweck, aber es macht deutlich dass die Variable nicht benötigt wird
# und auch unser Editor zeigt dann keine Warnung an.

print(names)

# %% [markdown]
# ### Lernkontrolle

# %%
# Erstellen einer Liste
# -----------------------------
# Erstelle eine Liste von Zahlen, die verschiedene Datentypen enthält (z.B. Integer, Floats und Strings).

# Schleife über die Liste
# ------------------------------
# Schreibe eine for-Schleife, die über die Liste iteriert.
# Für jeden Eintrag in der Liste:
# - Wenn es eine Zahl (Integer oder Float) ist, gib den Eintrag selbst sowie dessen Quadratwert aus.
# - Wenn es ein String ist, gib eine Meldung aus, die besagt, dass es sich um einen String handelt.
# - Wenn es etwas anderes ist, gib eine Fehlermeldung aus.

# Hinzufügen von Bedingungen
# ----------------------------------
# Ändere die for-Schleife, um folgende Bedingungen hinzuzufügen:
# - Wenn die Zahl gerade ist, gib eine zusätzliche Nachricht aus, die besagt, dass es sich um eine gerade Zahl handelt.
# - Wenn die Zahl ungerade ist, gib eine zusätzliche Nachricht aus, die besagt, dass es sich um eine ungerade Zahl handelt.
# - Wenn der String "Python" ist, gib eine zusätzliche Nachricht aus, die besagt, dass es sich um einen Python-String handelt.

# Testen der Schleife
# ---------------------------
# Teste deine for-Schleife mit verschiedenen Eingaben und überprüfe, ob die Ausgabe den Erwartungen entspricht.

# Beispiel-Ausgabe
# ----------------
# 4 ist eine gerade Zahl und sein Quadratwert ist 16.
# 'Hallo' ist ein String.
# 3 ist eine ungerade Zahl und sein Quadratwert ist 9.
# 'Python' ist ein String und es ist ein Python-String.

# %% [markdown]
# ## Teil 5: Klassen und Funktionen
#
# Dieser Teil soll euch in erster Linie dazu dienen, die zugrundeliegenden Konzepte zu verstehen. Funktionen werden relativ oft selbst geschrieben, aber Klassen werdet ihr in vielen Anwendungsbereichen von Python niemals selbst schreiben müssen. Trotzdem ist es nützlich zu wissen, wie sie funktionieren.
#
# Eine Klasse kannst Du dir wie eine Blaupause vorstellen. Sie stellt den Bauplan dar. Erst wenn wir ein Objekt "instantiieren" wird etwas fassbares daraus.
#
# Am leichtesten lernt man es an einem Beispiel:

# %%
class Dog:
    def __init__(self, name, breed):
        self.name = name
        self.rasse = breed

    def __str__(x):
        return f"Ein {x.rasse} mit Namen {x.name}."
    
    def bark():
        print("Wuff!")

# %% [markdown]
# Wird dieser Code ausgeführt, passiert erstmal nichts. Die Klasse wurde zwar definiert, aber noch kein Objekt instantiiert. Das tun wir auf diese Weise:

# %%
dog = Dog("Susi", "Dackel")

print(dog)

Dog.bark()

# %% [markdown]
# Die `init`-Methode (Wir nennen Funktionen innerhalb von Klassen "Methoden") ist notwendig für jede Klasse. Sie wird ausgeführt, wenn das Objekt instantiiert wird. Sie enthält ausserdem die Argumente `self`, `name` und `breed`. `self` ist wichtig für Klassen, diese Variable verweist auf das Objekt selbst. `name` und `breed` sind hingegen Argumente, die bei Instantiierung eines Objekts dieser Klasse angegbeben werden müssen. Sie werden dann in der `init`-Methode den "Attributen" `self.name` und `self.breed` zugewiesen. Attribute sind Eigenschaften des Objekts und können von überall in der Klasse angesteuert werden. In diesem Fall nutzen wir die Attribute in der `str`-Methode um den Namen und die Rasse des Hundes auszugeben. Die `str`-Methode enthalten viele Klassen, sie definiert, was ausgegeben wird, wenn das Objekt per `print` ausgegeben wird. Es gibt noch viele solcher "magischer Methoden".
# Schliesslich habe ich noch eine ganz eigene Methode definiert, die den Hund bellen lässt.

# %% [markdown]
# Wir können Funktionen auch losgelöst von Klassen schreiben. Oft wird das schon nur gemacht, um den Code sauber zu halten oder Repetitionen von längeren Codeblöcken zu vermeiden.
# Eine Notwendigkeit sind Funktionen spätestens dann, wenn ihr sie für Rekursion benötigt, zum Beispiel um einen XML-Baum bis zu den untersten Elementen zu durchsuchen.
#
# Im Folgenden Beispiel benutze ich eine rekursive Funktion um einen XML-Baum nach allen Vornamen zu durchsuchen die darin vorkommen.
# Die Datei befindet sich im gleichen Ordner wie dieses Dossier unter `catalogue.xml`.
#
# Ich sollte erwähnen, dass es mit XPath natürlich weitaus einfachere Möglichkeiten gibt, diese Aufgabe zu erfüllen, aber das stellt eine gute Demonstration von Rekursion dar:

# %%
# die XML-Bibliothek von Python
# "as et" lässt uns "et" als Alias für das Modul verwenden
import xml.etree.ElementTree as et

# Ich verwende hier explizites Typing für die Argumente, das ist optional!
def check_children(node : et.Element, first_names : list):
    # Wir prüfen, ob das Element ein first-name Tag ist
    if node.tag == "first-name":
        # Das text-Attribut enthält den Text zwischen den Tags
        first_names.append(node.text)

    # Man kann die Kinder eines Elements wie eine Liste iterieren
    for child in node: 
        # Wir überprüfen dann auch gleich die Kinder des Elements
        check_children(child, first_names)

# Wir lesen mit et.parse() die XML-Datei ein, und steuern das root-Element (library) mit getroot() an.
root = et.parse("catalogue.xml").getroot()
first_names = []
# Erst durch diesen Funktionsaufruf wird die Suche gestartet
check_children(root, first_names)

print(first_names)

# %% [markdown]
# Wir machen in diesem Beispiel grossen Nutzen von der Veränderbarkeit von Listen, daher brauchen wir keine `return`-Werte in unserer Funktion. Wir verändern die Liste einfach *in-place*.
#
# Ihr seht am obigen Beispiel, dass `def` eine Funktionsdeklaration ausmacht. Den Namen für die Funktion können wir, wie Variablennamen, frei wählen (Beachtet aber den Styleguide!). In der Klammer nach dem Namen schreiben wir unsere Funktionsargumente (auch Parameter genannt). In diesem Fall haben wir zwei Argumente, die beim Aufruf benötigt werden.
#
# Hier übrigens der optimierte Code, der XPath benutzt:

# %%
import xml.etree.ElementTree as et

root = et.parse("catalogue.xml").getroot()

first_name_nodes = root.findall(".//first-name")

first_names = [node.text for node in first_name_nodes]

print(first_names)

# %% [markdown]
# Schliesslich noch ein einfaches Beispiel mit `return`-Wert, um auch das noch zu demonstrieren. In diesem Fall preprocessen wir rudimentär Zeile für Zeile Moby Dick:

# %%
def preprocess_line(line, lower=False):
    # Entfernen von unnötigen Whitespaces
    line = line.strip()
    # Aufteilen in einzelne Wörter
    line = line.split()
    # Entfernen von Kommas, Punkten, Fragezeichen und Ausrufezeichen (auf ineffiziente Weise)
    line = [word.rstrip(",").rstrip(".").rstrip("!").rstrip("?") for word in line]
    # Kleinschreiben des Wortes
    # Aber nur wenn das Lower-Argument auf True gesetzt wird
    if lower:
        line = [word.lower() for word in line]
    # Die veränderte Zeile wird dann zurückgegeben
    return line

# So wird eine Datei zum Lesen geöffnet
infile = open("moby_dick.txt", mode="r", encoding="utf8")

# Python liest automatisch Dateien Zeile für Zeile, wenn man sie iteriert
for line in infile:
    # Ohne lowercasing (default)
    modified_line = preprocess_line(line)
    
    # Hier überschreibe ich das optionale Argument lower
    lowercased_line = preprocess_line(line, lower=True)

    # Alle Zeilen ausgeben, in denen der Wal erwähnt wird
    if "whale" in lowercased_line:
        print(lowercased_line)

# Nach dem Lesen wieder schliessen
infile.close()

# %% [markdown]
# ### Lernkontrolle:
#
# Keine Sorge, falls diese Übung etwas zu fortgeschritten ist. Versuche einfach mal dein Bestes, aber dieser Stoff ist zu diesem Zeitpunkt noch sehr anspruchsvoll.

# %%
# Erstellen einer Liste
# -----------------------------
# Erstelle eine Liste von Zahlen.

# Schreiben einer Funktion
# --------------------------------
# Schreibe eine Funktion, die die Liste als Argument akzeptiert und die Summe aller geraden Zahlen in der Liste zurückgibt.

# Verwenden der Funktion
# -----------------------------
# Rufe die Funktion mit der zuvor erstellten Liste als Argument auf und gib das Ergebnis aus.

# Bedingungen hinzufügen
# -----------------------------
# Ändere die Funktion, um folgende Bedingungen hinzuzufügen:
# - Wenn die Liste leer ist, gib eine Fehlermeldung aus.
# - Wenn es in der Liste keine geraden Zahlen gibt, gib eine Meldung aus, die besagt, dass keine geraden Zahlen vorhanden sind.

# Testen der Funktion
# ---------------------------
# Teste die Funktion mit verschiedenen Eingaben und überprüfe, ob die Ausgabe den Erwartungen entspricht.

# Beispiel-Ausgabe
# ----------------
# Die Liste ist: [1, 2, 3, 4, 5, 6, 7, 8, 9]
# Die Summe aller geraden Zahlen in der Liste beträgt: 20

# Die Liste ist: [1, 3, 5, 7, 9]
# In der Liste sind keine geraden Zahlen vorhanden.

# Die Liste ist: []
# Die Liste ist leer.
